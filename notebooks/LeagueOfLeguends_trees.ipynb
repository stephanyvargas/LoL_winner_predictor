# %% [markdown]
# # Import data
# Training data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import get_train_data_only
df_teams, df_BLUE, df_RED = get_train_data_only()

# %%
#How many data points we have
len(df_teams), len(df_BLUE), len(df_RED)
# Out:
# (30465, 152325, 152325)

# %% [markdown]
# ## Rebuild the data into a df that simulates the one we will receive from the web

# %%
import numpy as np 
import pandas as pd
from tqdm import tqdm

# %%
def rearrange_df(df):
    df_top = df[['champion_id', 'game_id']][df.role == 'TOP']
    df_jgl = df[['champion_id', 'game_id']][df.role == 'JGL']
    df_top_jgl = pd.merge(df_top.rename(columns={'champion_id': 'TOP'}), df_jgl.rename(columns={'champion_id': 'JGL'}), on='game_id')

    df_bot = df[['champion_id', 'game_id']][df.role == 'BOT']
    df_mid = df[['champion_id', 'game_id']][df.role == 'MID']
    df_bot_mid = pd.merge(df_bot.rename(columns={'champion_id': 'BOT'}), df_mid.rename(columns={'champion_id': 'MID'}), on='game_id')

    df_top_jgl_bot_mid = pd.merge(df_top_jgl, df_bot_mid, on='game_id')

    df_sup = df[['champion_id', 'game_id']][df.role == 'SUP']
    df_top_jgl_bot_mid_sup = pd.merge(df_top_jgl_bot_mid, df_sup.rename(columns={'champion_id': 'SUP'}), on='game_id')
    return df_top_jgl_bot_mid_sup

# %%
df_blue = rearrange_df(df_BLUE)
df_red = rearrange_df(df_RED)
data = pd.merge(df_blue, df_red, on='game_id')

# %%
#side that won
df_teams['game_id'] = df_teams['id']
#df_teams[['winner', 'game_id']]

# %%
full_data = pd.merge(data, df_teams[['winner', 'game_id']], on='game_id')
full_data
# Out:
#        TOP_x                                            game_id  JGL_x  BOT_x  \
# 0        223            OPL/2016 Season/Split 1/Scoreboards_4_2    421    236
# 1        245  Latin America Cup/LAN/2016 Season/Closing Cup/...    421     51
# 2         57     OPL/2016 Season/Split 2/Scoreboards/Week 2_2_3    203     67
# 3        245     OPL/2016 Season/Split 2/Scoreboards/Week 2_2_2    154    236
# 4        245     OPL/2016 Season/Split 2/Scoreboards/Week 2_2_1    421     51
# ...      ...                                                ...    ...    ...
# 30460    516  Liga Nexo/2020 Season/G2 Arctic Showmatch/Scor...    141     21
# 30461    420  Liga Nexo/2020 Season/Split 1/Scoreboards/Week...    245    134
# 30462     24  Liga Nexo/2020 Season/Split 1/Scoreboards/Week...    104    134
# 30463     62  Liga Nexo/2020 Season/Split 1/Scoreboards/Week...     59    523
# 30464     41  Liga Nexo/2020 Season/G2 Arctic Showmatch/Scor...      2    115
#
#        MID_x  SUP_x  TOP_y  JGL_y  BOT_y  MID_y  SUP_y winner
# 0        112    412    117     36     18     99     48   BLUE
# 1        112     43     57    104     15     26    201   BLUE
# 2        268    201     48     60     81    112    412    RED
# 3         41    432     57    203     81    112     48    RED
# 4         13    201     57    203     81      4    432    RED
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# 30460     84    875     41    113    523    268     40   BLUE
# 30461     58    432    516     48     21    161    350    RED
# 30462     57     44     41     30     21    516    143   BLUE
# 30463     61     40     58    154     21    134    143   BLUE
# 30464    134     43    114    427    523    238    432    RED
#
# [30465 rows x 12 columns]

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Pipe with logit regression

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector
from sklearn import set_config; set_config(display='diagram')
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier


from transformers import SynergyFeature, RoleFeature, ChampionWinrateFeature 

# Paralellize column transformers
preproc = ColumnTransformer([
    ('synergy_blue', SynergyFeature(), ['TOP_x', 'JGL_x','BOT_x','MID_x','SUP_x']),
    ('synergy_red', SynergyFeature(), ['TOP_y', 'JGL_y','BOT_y','MID_y','SUP_y']),
    ('winrate_blue', ChampionWinrateFeature(), ['TOP_x', 'JGL_x','BOT_x','MID_x','SUP_x']),
    ('winrate_red', ChampionWinrateFeature(), ['TOP_y', 'JGL_y','BOT_y','MID_y','SUP_y']),
    ('TOP_rate', RoleFeature('TOP'), ['TOP_x', 'TOP_y']),
    ('SUP_rate', RoleFeature('SUP'), ['SUP_x', 'SUP_y']),
    ('MID_rate', RoleFeature('MID'), ['MID_x', 'MID_y']),
    ('BOT_rate', RoleFeature('BOT'), ['BOT_x', 'BOT_y']),
    ('JGL_rate', RoleFeature('JGL'), ['JGL_x', 'JGL_y'])
    ])

#add model
#pipe = make_pipeline(preproc, DecisionTreeClassifier(criterion='entropy', max_depth= 14, random_state=42))

bagged_tree = BaggingClassifier(DecisionTreeClassifier(criterion='entropy', max_depth= 14, random_state=42), n_estimators=40)
pipe = make_pipeline(preproc, bagged_tree)

pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('synergy_blue',
#                                                   SynergyFeature(),
#                                                   ['TOP_x', 'JGL_x', 'BOT_x',
#                                                    'MID_x', 'SUP_x']),
#                                                  ('synergy_red',
#                                                   SynergyFeature(),
#                                                   ['TOP_y', 'JGL_y', 'BOT_y',
#                                                    'MID_y', 'SUP_y']),
#                                                  ('winrate_blue',
#                                                   ChampionWinrateFeature(),
#                                                   ['TOP_x', 'JGL_x', 'BOT_x',
#                                                    'MID_x', 'SUP_x']),
#                                                  ('winrate_red',
#                                                   ChampionWinrateFeature(),
#                                                   ['TOP_...
#                                                   RoleFeature(role='SUP'),
#                                                   ['SUP_x', 'SUP_y']),
#                                                  ('MID_rate',
#                                                   RoleFeature(role='MID'),
#                                                   ['MID_x', 'MID_y']),
#                                                  ('BOT_rate',
#                                                   RoleFeature(role='BOT'),
#                                                   ['BOT_x', 'BOT_y']),
#                                                  ('JGL_rate',
#                                                   RoleFeature(role='JGL'),
#                                                   ['JGL_x', 'JGL_y'])])),
#                 ('baggingclassifier',
#                  BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                          max_depth=14,
#                                                                          random_state=42),
#                                    n_estimators=40))])

# %%
from sklearn.preprocessing import LabelEncoder

y_train = LabelEncoder().fit(full_data.winner).transform(full_data.winner)
X_train = full_data.drop(['game_id', 'winner'], axis=1)

# %%
#get the parameters of the pipe
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('synergy_blue', SynergyFeature(),
#                                     ['TOP_x', 'JGL_x', 'BOT_x', 'MID_x', 'SUP_x']),
#                                    ('synergy_red', SynergyFeature(),
#                                     ['TOP_y', 'JGL_y', 'BOT_y', 'MID_y', 'SUP_y']),
#                                    ('winrate_blue', ChampionWinrateFeature(),
#                                     ['TOP_x', 'JGL_x', 'BOT_x', 'MID_x', 'SUP_x']),
#                                    ('winrate_red', ChampionWinrateFeature(),
#                                     ['TOP_y', 'JGL_y', 'BOT_y', 'MID_y', 'SUP_y']),
#                                    ('TOP_rate', RoleFeature(role='TOP'),
#                                     ['TOP_x', 'TOP_y']),
#                                    ('SUP_rate', RoleFeature(role='SUP'),
#                                     ['SUP_x', 'SUP_y']),
#                                    ('MID_rate', RoleFeature(role='MID'),
#                                     ['MID_x', 'MID_y']),
#                                    ('BOT_rate', RoleFeature(role='BOT'),
#                                     ['BOT_x', 'BOT_y']),
#                                    ('JGL_rate', RoleFeature(role='JGL'),
#                                     ['JGL_x', 'JGL_y'])])),
#   ('decisiontreeclassifier', DecisionTreeClassifier(random_state=42))],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('synergy_blue', SynergyFeature(),
#                                   ['TOP_x', 'JGL_x', 'BOT_x', 'MID_x', 'SUP_x']),
#                                  ('synergy_red', SynergyFeature(),
#                                   ['TOP_y', 'JGL_y', 'BOT_y', 'MID_y', 'SUP_y']),
#                                  ('winrate_blue', ChampionWinrateFeature(),
#                                   ['TOP_x', 'JGL_x', 'BOT_x', 'MID_x', 'SUP_x']),
#                                  ('winrate_red', ChampionWinrateFeature(),
#                                   ['TOP_y', 'JGL_y', 'BOT_y', 'MID_y', 'SUP_y']),
#                                  ('TOP_rate', RoleFeature(role='TOP'),
#                                   ['TOP_x', 'TOP_y']),
#                                  ('SUP_rate', RoleFeature(role='SUP'),
#                                   ['SUP_x', 'SUP_y']),
#                                  ('MID_rate', RoleFeature(role='MID'),
#                                   ['MID_x', 'MID_y']),
#                                  ('BOT_rate', RoleFeature(role='BOT'),
#                                   ['BOT_x', 'BOT_y']),
#                                  ('JGL_rate', RoleFeature(role='JGL'),
#                                   ['JGL_x', 'JGL_y'])]),
#  'decisiontreeclassifier': DecisionTreeClassifier(random_state=42),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('synergy_blue',
#    SynergyFeature(),
#    ['TOP_x', 'JGL_x', 'BOT_x', 'MID_x', 'SUP_x']),
#   ('synergy_red',
#    SynergyFeature(),
#    ['TOP_y', 'JGL_y', 'BOT_y', 'MID_y', 'SUP_y']),
#   ('winrate_blue',
#    ChampionWinrateFeature(),
#    ['TOP_x', 'JGL_x', 'BOT_x', 'MID_x', 'SUP_x']),
#   ('winrate_red',
#    ChampionWinrateFeature(),
#    ['TOP_y', 'JGL_y', 'BOT_y', 'MID_y', 'SUP_y']),
#   ('TOP_rate', RoleFeature(role='TOP'), ['TOP_x', 'TOP_y']),
#   ('SUP_rate', RoleFeature(role='SUP'), ['SUP_x', 'SUP_y']),
#   ('MID_rate', RoleFeature(role='MID'), ['MID_x', 'MID_y']),
#   ('BOT_rate', RoleFeature(role='BOT'), ['BOT_x', 'BOT_y']),
#   ('JGL_rate', RoleFeature(role='JGL'), ['JGL_x', 'JGL_y'])],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__synergy_blue': SynergyFeature(),
#  'columntransformer__synergy_red': SynergyFeature(),
#  'columntransformer__winrate_blue': ChampionWinrateFeature(),
#  'columntransformer__winrate_red': ChampionWinrateFeature(),
#  'columntransformer__TOP_rate': RoleFeature(role='TOP'),
#  'columntransformer__SUP_rate': RoleFeature(role='SUP'),
#  'columntransformer__MID_rate': RoleFeature(role='MID'),
#  'columntransformer__BOT_rate': RoleFeature(role='BOT'),
#  'columntransformer__JGL_rate': RoleFeature(role='JGL'),
#  'columntransformer__TOP_rate__role': 'TOP',
#  'columntransformer__SUP_rate__role': 'SUP',
#  'columntransformer__MID_rate__role': 'MID',
#  'columntransformer__BOT_rate__role': 'BOT',
#  'columntransformer__JGL_rate__role': 'JGL',
#  'decisiontreeclassifier__ccp_alpha': 0.0,
#  'decisiontreeclassifier__class_weight': None,
#  'decisiontreeclassifier__criterion': 'gini',
#  'decisiontreeclassifier__max_depth': None,
#  'decisiontreeclassifier__max_features': None,
#  'decisiontreeclassifier__max_leaf_nodes': None,
#  'decisiontreeclassifier__min_impurity_decrease': 0.0,
#  'decisiontreeclassifier__min_samples_leaf': 1,
#  'decisiontreeclassifier__min_samples_split': 2,
#  'decisiontreeclassifier__min_weight_fraction_leaf': 0.0,
#  'decisiontreeclassifier__random_state': 42,
#  'decisiontreeclassifier__splitter': 'best'}

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy import stats

# Instanciate grid search
grid = {'decisiontreeclassifier__max_depth':stats.randint(1,100), 'decisiontreeclassifier__criterion':['gini','entropy']}

grid_search = RandomizedSearchCV(
    pipe, grid,
    scoring="accuracy",
    cv=5,
    n_jobs=-1, 
    verbose=1)

#fit data to grid
grid_search.fit(X_train, y_train)
grid_search.best_params_, grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ({'decisiontreeclassifier__criterion': 'entropy',
#   'decisiontreeclassifier__max_depth': 14},
#  Pipeline(steps=[('columntransformer',
#                   ColumnTransformer(transformers=[('synergy_blue',
#                                                    SynergyFeature(),
#                                                    ['TOP_x', 'JGL_x', 'BOT_x',
#                                                     'MID_x', 'SUP_x']),
#                                                   ('synergy_red',
#                                                    SynergyFeature(),
#                                                    ['TOP_y', 'JGL_y', 'BOT_y',
#                                                     'MID_y', 'SUP_y']),
#                                                   ('winrate_blue',
#                                                    ChampionWinrateFeature(),
#                                                    ['TOP_x', 'JGL_x', 'BOT_x',
#                                                     'MID_x', 'SUP_x']),
#                                                   ('winrate_red',
#                                                    ChampionWinrateFeature(),
#                                                    ['TOP_...
#                                                    RoleFeature(role='TOP'),
#                                                    ['TOP_x', 'TOP_y']),
#                                                   ('SUP_rate',
#                                                    RoleFeature(role='SUP'),
#                                                    ['SUP_x', 'SUP_y']),
#                                                   ('MID_rate',
#                                                    RoleFeature(role='MID'),
#                                                    ['MID_x', 'MID_y']),
#                                                   ('BOT_rate',
#                                                    RoleFeature(role='BOT'),
#                                                    ['BOT_x', 'BOT_y']),
#                                                   ('JGL_rate',
#                                                    RoleFeature(role='JGL'),
#                                                    ['JGL_x', 'JGL_y'])])),
#                  ('decisiontreeclassifier',
#                   DecisionTreeClassifier(criterion='entropy', max_depth=14,
#                                          random_state=42))]))

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('synergy_blue',
#                                                   SynergyFeature(),
#                                                   ['TOP_x', 'JGL_x', 'BOT_x',
#                                                    'MID_x', 'SUP_x']),
#                                                  ('synergy_red',
#                                                   SynergyFeature(),
#                                                   ['TOP_y', 'JGL_y', 'BOT_y',
#                                                    'MID_y', 'SUP_y']),
#                                                  ('winrate_blue',
#                                                   ChampionWinrateFeature(),
#                                                   ['TOP_x', 'JGL_x', 'BOT_x',
#                                                    'MID_x', 'SUP_x']),
#                                                  ('winrate_red',
#                                                   ChampionWinrateFeature(),
#                                                   ['TOP_...
#                                                   RoleFeature(role='SUP'),
#                                                   ['SUP_x', 'SUP_y']),
#                                                  ('MID_rate',
#                                                   RoleFeature(role='MID'),
#                                                   ['MID_x', 'MID_y']),
#                                                  ('BOT_rate',
#                                                   RoleFeature(role='BOT'),
#                                                   ['BOT_x', 'BOT_y']),
#                                                  ('JGL_rate',
#                                                   RoleFeature(role='JGL'),
#                                                   ['JGL_x', 'JGL_y'])])),
#                 ('baggingclassifier',
#                  BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                          max_depth=14,
#                                                                          random_state=42),
#                                    n_estimators=40))])

# %%
from sklearn.model_selection import cross_val_score

# Cross validate pipeline
cross_val_score(pipe, X_train, y_train, cv=2, scoring='accuracy').mean()

# %%
import joblib

joblib.dump(pipe, 'model_tree.joblib')
# Out:
# ['model_tree.joblib']

# %% [markdown]
# # Use the test data

# %% [markdown]
# ## Import the test data

# %%
#Import the data through the utils file
test_teams, test_BLUE, test_RED = get_train_data_only(train_data = False, test_data = True)
len(test_teams), len(test_BLUE), len(test_RED)
# Out:
# (4771, 23855, 23855)

# %%
#Fix the dataframe with the columns we need
test_blue = rearrange_df(test_BLUE)
test_red = rearrange_df(test_RED)
test_data = pd.merge(test_blue, test_red, on='game_id')
test_data
# Out:
#       TOP_x                                            game_id  JGL_x  BOT_x  \
# 0       516  UK League Championship/2021 Season/Spring Seas...    104    523
# 1       516  LFL Division 2/2021 Season/Spring Season/Score...    104    360
# 2        98    LPLOL/2021 Season/Spring Season/Scoreboards_4_1      2    523
# 3        58     Esports Balkan League/Season 8/Scoreboards_3_1    163    145
# 4        58  Belgian League/2021 Season/Spring Split/Scoreb...    876     81
# ...     ...                                                ...    ...    ...
# 4766    150  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...    245    222
# 4767     54  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...     25    222
# 4768    516  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...     64    145
# 4769     54  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...     56    145
# 4770     58  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...    131    222
#
#       MID_x  SUP_x  TOP_y  JGL_y  BOT_y  MID_y  SUP_y
# 0       112    412     79    876     21     18    201
# 1       112    526     41     76    145    126     89
# 2         4    412    516    876    145    777     53
# 3         3    497     79    113    523     38    201
# 4       112     57     79     76    145    777    526
# ...     ...    ...    ...    ...    ...    ...    ...
# 4766     64    201     98     56    145    517     89
# 4767    112    111    164    121     81     96     40
# 4768     13    201    164    876     67     61    526
# 4769     84    526    150     77     96    134    117
# 4770    157     12     64    121    145      8    497
#
# [4771 rows x 11 columns]

# %%
#get the side that won
test_teams['game_id'] = test_teams['id']
test_teams[['winner', 'game_id']].head()
# Out:
#       winner                                            game_id
# 27183   BLUE  UK League Championship/2021 Season/Spring Seas...
# 27184    RED  LFL Division 2/2021 Season/Spring Season/Score...
# 27194   BLUE    LPLOL/2021 Season/Spring Season/Scoreboards_4_1
# 27181   BLUE     Esports Balkan League/Season 8/Scoreboards_3_1
# 27180    RED  Belgian League/2021 Season/Spring Split/Scoreb...

# %%
full_test_data = pd.merge(test_data, test_teams[['winner', 'game_id']], on='game_id')
full_test_data
# Out:
#       TOP_x                                            game_id  JGL_x  BOT_x  \
# 0       516  UK League Championship/2021 Season/Spring Seas...    104    523
# 1       516  LFL Division 2/2021 Season/Spring Season/Score...    104    360
# 2        98    LPLOL/2021 Season/Spring Season/Scoreboards_4_1      2    523
# 3        58     Esports Balkan League/Season 8/Scoreboards_3_1    163    145
# 4        58  Belgian League/2021 Season/Spring Split/Scoreb...    876     81
# ...     ...                                                ...    ...    ...
# 4766    150  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...    245    222
# 4767     54  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...     25    222
# 4768    516  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...     64    145
# 4769     54  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...     56    145
# 4770     58  Magyar Nemzeti E-sport Bajnokság/Season 3/Scor...    131    222
#
#       MID_x  SUP_x  TOP_y  JGL_y  BOT_y  MID_y  SUP_y winner
# 0       112    412     79    876     21     18    201   BLUE
# 1       112    526     41     76    145    126     89    RED
# 2         4    412    516    876    145    777     53   BLUE
# 3         3    497     79    113    523     38    201   BLUE
# 4       112     57     79     76    145    777    526    RED
# ...     ...    ...    ...    ...    ...    ...    ...    ...
# 4766     64    201     98     56    145    517     89   BLUE
# 4767    112    111    164    121     81     96     40   BLUE
# 4768     13    201    164    876     67     61    526   BLUE
# 4769     84    526    150     77     96    134    117   BLUE
# 4770    157     12     64    121    145      8    497    RED
#
# [4771 rows x 12 columns]

# %%
np.unique(test_teams.patch)
# Out:
# array([11.1, 11.2, 11.3, 11.4, 11.5, 11.6, 11.7, 11.8, 11.9],
#       dtype=float32)

# %% [markdown]
# ## Test the data

# %%
y_test = LabelEncoder().fit(full_test_data.winner).transform(full_test_data.winner)
X_test = full_test_data.drop(['game_id', 'winner'], axis=1)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6719765248375602

# %%
from sklearn import metrics

predicted = pipe.predict(X_test)
print(metrics.accuracy_score(y_test, predicted))
print(metrics.classification_report(y_test, predicted))
# Out:
# 0.6719765248375602
#               precision    recall  f1-score   support
#
#            0       0.68      0.76      0.71      2583
#            1       0.67      0.57      0.61      2188
#
#     accuracy                           0.67      4771
#    macro avg       0.67      0.66      0.66      4771
# weighted avg       0.67      0.67      0.67      4771
