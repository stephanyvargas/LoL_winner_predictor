# %% [markdown]
# # Work on Sample data from League of Legends

# %%
import numpy as np
import pandas as pd
import json

file = '../raw_data/full_dump.json'
with open(file) as data_file:    
    data = json.load(data_file)
len(data)
# Out:
# 35320

# %%
data_keys = list(data.keys())
data_keys[:5]
# Out:
# ['EU Challenger Series/2017 Season/Spring Qualifiers/Scoreboards_1_1',
#  'EU Challenger Series/2017 Season/Spring Qualifiers/Scoreboards_2_1',
#  'EU Challenger Series/2017 Season/Spring Qualifiers/Scoreboards_3_1',
#  'EU Challenger Series/2017 Season/Spring Qualifiers/Scoreboards_4_1',
#  'EU Challenger Series/2017 Season/Spring Qualifiers/Scoreboards_5_1']

# %%
import re

pattern = r'(\d{4})'
re.search(pattern, data_keys[2]).group(1)

year = []
no_year = []
for i in range(len(data_keys)):
    try:
        year.append(re.search(pattern, data_keys[i]).group(1))
    except:
        no_year.append(data_keys[i])

np.unique(year), len(no_year)
# Out:
# (array(['2016', '2017', '2018', '2019', '2020', '2021'], dtype='<U4'), 1703)

# %% [markdown]
# ## Normalize the JSON file into a Pandas DataFrame
#
# Data is structured in a JSON structure that is inconvinient for data analysis. Converting nested JSON structures to Pandas DataFrames using https://medium.com/swlh/converting-nested-json-structures-to-pandas-dataframes-e8106c59976e

# %%
#Normalize the complete dataframe and make a copy
df_normalized_teams = pd.json_normalize(data.values())
df_teams = df_normalized_teams.copy()
df_teams.sample(10)
# Out:
#                                                       id start  patch winner  \
# 15063  NA Academy League/2019 Season/Summer Season/Sc...  None   9.13   BLUE
# 30465     LCO/2021 Season/Split 1/Scoreboards/Week 5_4_1  None   11.5   BLUE
# 31616   NA LCS/2016 Season/Spring Season/Scoreboards_8_1  None    6.1   BLUE
# 28081  CBLOL Academy/2021 Season/Split 1/Scoreboards/...  None   11.2   BLUE
# 25965  Greek Legends League/2020 Season/Winter Season...  None  10.20   BLUE
# 30096  LCK CL/2021 Season/Spring Season/Scoreboards/W...  None   11.5   BLUE
# 7271   LCK/2018 Season/Summer Season/Scoreboards/Week...  None   8.11   BLUE
# 19075  TCL/2020 Season/Winter Season/Scoreboards/Week...  None   10.3   BLUE
# 31152   LLA/2021 Season/Opening Playoffs/Scoreboards_3_2  None   11.6   BLUE
# 23691  Turkey Academy League/2020 Season/Summer Seaso...  None  10.14    RED
#
#        duration                                         picks_bans  \
# 15063      1735  [{'champion_name': 'Irelia', 'is_ban': True}, ...
# 30465      2065  [{'champion_name': 'Thresh', 'is_ban': True}, ...
# 31616      2609                                                 []
# 28081      1586  [{'champion_name': 'Sett', 'is_ban': True}, {'...
# 25965      1976  [{'champion_name': 'Graves', 'is_ban': True}, ...
# 30096      1909  [{'champion_name': 'Thresh', 'is_ban': True}, ...
# 7271       1393  [{'champion_name': 'Shen', 'is_ban': True}, {'...
# 19075      2201  [{'champion_name': 'Gragas', 'is_ban': True}, ...
# 31152      2192  [{'champion_name': 'Udyr', 'is_ban': True}, {'...
# 23691      1831                                                 []
#
#                     teams.BLUE.name  teams.BLUE.total_turret_kills  \
# 15063           Team Liquid Academy                              9
# 30465           Chiefs Esports Club                              9
# 31616                           TSM                              7
# 28081              Cruzeiro Academy                              7
# 25965  Anorthosis Famagusta Esports                              9
# 30096             Gen.G Challengers                              6
# 7271                     KT Rolster                              9
# 19075                  Dark Passage                              9
# 31152                Furious Gaming                              9
# 23691           Galatasaray Academy                              3
#
#        teams.BLUE.total_inhibitor_kills  teams.BLUE.total_rift_herald_kills  \
# 15063                                 1                                   1
# 30465                                 1                                   2
# 31616                                 1                                   2
# 28081                                 1                                   1
# 25965                                 1                                   0
# 30096                                 1                                   0
# 7271                                  2                                   0
# 19075                                 1                                   2
# 31152                                 1                                   2
# 23691                                 0                                   2
#
#        ...  teams.BLUE.side  \
# 15063  ...             BLUE
# 30465  ...             BLUE
# 31616  ...             BLUE
# 28081  ...             BLUE
# 25965  ...             BLUE
# 30096  ...             BLUE
# 7271   ...             BLUE
# 19075  ...             BLUE
# 31152  ...             BLUE
# 23691  ...             BLUE
#
#                                       teams.BLUE.players  \
# 15063  [{'name': 'Jenkins', 'id': 220331, 'role': 'TO...
# 30465  [{'name': 'Lived', 'id': 303244, 'role': 'TOP'...
# 31616  [{'name': 'Hauntzer', 'id': 164344, 'role': 'T...
# 28081  [{'name': 'Reversed', 'id': 400492, 'role': 'T...
# 25965  [{'name': 'WouLou', 'id': 204021, 'role': 'TOP...
# 30096  [{'name': 'Lonely', 'id': 272225, 'role': 'TOP...
# 7271   [{'name': 'Smeb', 'id': 197924, 'role': 'TOP',...
# 19075  [{'name': 'Juuzou', 'id': 280652, 'role': 'TOP...
# 31152  [{'name': 'Jauny', 'id': 279392, 'role': 'TOP'...
# 23691  [{'name': 'NuQ', 'id': 399288, 'role': 'TOP', ...
#
#                                teams.RED.name teams.RED.total_turret_kills  \
# 15063                             CLG Academy                            1
# 30465                                Gravitas                            1
# 31616                             Team Liquid                            7
# 28081                           Vorax Academy                            2
# 25965                          Team Phantasma                            3
# 30096           Nongshim RedForce Challengers                            3
# 7271                           Afreeca Freecs                            1
# 19075                        Beşiktaş Esports                            1
# 31152  Infinity Esports (Latin American Team)                            4
# 23691                     Team AURORA Academy                           11
#
#       teams.RED.total_inhibitor_kills  teams.RED.total_rift_herald_kills  \
# 15063                               0                                  0
# 30465                               0                                  0
# 31616                               1                                  0
# 28081                               0                                  1
# 25965                               0                                  2
# 30096                               0                                  2
# 7271                                0                                  1
# 19075                               0                                  0
# 31152                               0                                  0
# 23691                               3                                  0
#
#        teams.RED.total_dragon_kills  teams.RED.total_baron_kills  \
# 15063                             0                            0
# 30465                             2                            0
# 31616                             2                            1
# 28081                             2                            0
# 25965                             3                            0
# 30096                             1                            0
# 7271                              0                            0
# 19075                             3                            0
# 31152                             1                            1
# 23691                             2                            1
#
#        teams.RED.side                                  teams.RED.players
# 15063             RED  [{'name': 'FallenBandit', 'id': 159119, 'role'...
# 30465             RED  [{'name': 'Safa', 'id': 457420, 'role': 'TOP',...
# 31616             RED  [{'name': 'Lourlo', 'id': 180523, 'role': 'TOP...
# 28081             RED  [{'name': 'Yupps', 'id': 349556, 'role': 'TOP'...
# 25965             RED  [{'name': 'Bako', 'id': 252099, 'role': 'TOP',...
# 30096             RED  [{'name': 'DnDn', 'id': 423672, 'role': 'TOP',...
# 7271              RED  [{'name': 'Kiin', 'id': 176422, 'role': 'TOP',...
# 19075             RED  [{'name': 'Rare', 'id': 194867, 'role': 'TOP',...
# 31152             RED  [{'name': 'Buggax', 'id': 193123, 'role': 'TOP...
# 23691             RED  [{'name': 'Asteroid', 'id': 304606, 'role': 'T...
#
# [10 rows x 22 columns]

# %%
#Make a dataframe dedicated to the teams 
df_teams.drop(['teams.BLUE.players', 'teams.RED.players', 'picks_bans'], axis=1, inplace=True)
df_teams
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/tp/c_dxvgzd79d8p3xqyzj8p0pr0000gn/T/ipykernel_8822/3549647726.py in <module>
#       1 #Make a dataframe dedicated to the teams
# ----> 2 df_teams.drop(['teams.BLUE.players', 'teams.RED.players', 'picks_bans'], axis=1, inplace=True)
#       3 df_teams
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['teams.BLUE.players' 'teams.RED.players' 'picks_bans'] not found in axis"

# %%
#Make a dataframe dedicated to the team BLUE
df_normalized_teams['teams.BLUE.players'].explode()
df_normalized_BLUE = pd.json_normalize(df_normalized_teams['teams.BLUE.players'].explode())
df_BLUE = df_normalized_BLUE.copy()
df_BLUE.head(5)
# Out:
#        name        id role champion_name  champion_id  gold_15  \
# 0     Kikis  172122.0  TOP      Nautilus          111   5326.0
# 1    Broxah  193072.0  JGL       Lee Sin           64   5261.0
# 2     Nisqy  185791.0  MID        Syndra          134   6009.0
# 3  MrRallez  183407.0  BOT          Jhin          202   5304.0
# 4      Klaj  171882.0  SUP         Karma           43   2767.0
#
#    kills_assists_15  deaths_15  total_gold  total_cs  total_kills  \
# 0               8.0        1.0       12504       233            2
# 1              11.0        1.0       12352       153            4
# 2              13.0        1.0       13393       229            5
# 3              11.0        0.0       13969       315            2
# 4              12.0        0.0        9740        38            1
#
#    total_monster_kills  total_assists  total_deaths  total_damage_taken  \
# 0                    0              6             1               18220
# 1                  132              7             1               22212
# 2                    6              8             1               10647
# 3                    5              9             0                9758
# 4                    0             11             0               11917
#
#    total_damage_dealt   win  side
# 0              156270  True  BLUE
# 1              152183  True  BLUE
# 2              177681  True  BLUE
# 3              228328  True  BLUE
# 4               34299  True  BLUE

# %%
#Make a dataframe dedicated to the team RED
df_normalized_teams['teams.RED.players'].explode()
df_normalized_RED = pd.json_normalize(df_normalized_teams['teams.RED.players'].explode())
df_RED = df_normalized_RED.copy()
df_RED.head(5)
# Out:
#         name        id role champion_name  champion_id  gold_15  \
# 0     Phones  193289.0  TOP        Maokai           57   4528.0
# 1    Obvious  187241.0  JGL        Rengar          107   4728.0
# 2  MagiFelix  181359.0  MID          Ryze           13   4893.0
# 3    Sedrion  197437.0  BOT         Varus          110   5133.0
# 4     Noxiak  185879.0  SUP          Nami          267   2521.0
#
#    kills_assists_15  deaths_15  total_gold  total_cs  total_kills  \
# 0               2.0        7.0        9611       190            1
# 1               2.0        1.0        9640       174            0
# 2               2.0        3.0       11840       301            0
# 3               2.0        1.0       12010       283            2
# 4               2.0        2.0        7348        16            0
#
#    total_monster_kills  total_assists  total_deaths  total_damage_taken  \
# 0                   13              1             7               41065
# 1                  126              2             1               27879
# 2                    2              2             3               16013
# 3                    1              0             1               10370
# 4                    0              2             2               13815
#
#    total_damage_dealt    win side
# 0              111536  False  RED
# 1              147035  False  RED
# 2              205899  False  RED
# 3              184927  False  RED
# 4               15418  False  RED

# %%
#Make a dataframe dedicated to the Bans
df_normalized_teams['picks_bans'].explode()
df_normalized_BANS = pd.json_normalize(df_normalized_teams['picks_bans'].explode())
df_BANS = df_normalized_BANS.copy()
df_BANS.isnull().sum()/len(df_BANS)
# Out:
# champion_name    0.019285
# is_ban           0.019285
# dtype: float64

# %%
get_index = df_normalized_teams['id'].tolist()
index_preproc = np.asarray([[index] * 5 for index in get_index])
index_teams = index_preproc.reshape(len(df_normalized_teams) * 5).tolist()
df_RED['game_id'] = index_teams
df_BLUE['game_id'] = index_teams
len(index_teams)/5
# Out:
# 35320.0

# %%
df_BLUE['win'].value_counts()
# Out:
# True     94620
# False    81980
# Name: win, dtype: int64

# %%
df_RED['win'].value_counts()
# Out:
# False    94620
# True     81980
# Name: win, dtype: int64

# %%
df_BLUE['win']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 176595    True
# 176596    True
# 176597    True
# 176598    True
# 176599    True
# Name: win, Length: 176600, dtype: bool

# %%
df_BLUE_WIN = df_BLUE[df_BLUE['win'] == True]
df_BLUE_WIN
#Use dictionary Champion ID
# Out:
#             name        id role champion_name  champion_id  gold_15  \
# 0          Kikis  172122.0  TOP      Nautilus          111   5326.0
# 1         Broxah  193072.0  JGL       Lee Sin           64   5261.0
# 2          Nisqy  185791.0  MID        Syndra          134   6009.0
# 3       MrRallez  183407.0  BOT          Jhin          202   5304.0
# 4           Klaj  171882.0  SUP         Karma           43   2767.0
# ...          ...       ...  ...           ...          ...      ...
# 176595     CuVee  145319.0  TOP        Maokai           57   5940.0
# 176596  Ambition  189721.0  JGL       Lee Sin           64   6063.0
# 176597     Crown  142619.0  MID        Viktor          112   5926.0
# 176598     Ruler  196493.0  BOT        Ezreal           81   5784.0
# 176599    CoreJJ  137426.0  SUP         Braum          201   3392.0
#
#         kills_assists_15  deaths_15  total_gold  total_cs  total_kills  \
# 0                    8.0        1.0       12504       233            2
# 1                   11.0        1.0       12352       153            4
# 2                   13.0        1.0       13393       229            5
# 3                   11.0        0.0       13969       315            2
# 4                   12.0        0.0        9740        38            1
# ...                  ...        ...         ...       ...          ...
# 176595               9.0        1.0       11857       260            3
# 176596              13.0        2.0       11399       146            6
# 176597              13.0        1.0       13043       245            7
# 176598               8.0        2.0       11857       239            3
# 176599              12.0        2.0        7463        35            0
#
#         total_monster_kills  total_assists  total_deaths  total_damage_taken  \
# 0                         0              6             1               18220
# 1                       132              7             1               22212
# 2                         6              8             1               10647
# 3                         5              9             0                9758
# 4                         0             11             0               11917
# ...                     ...            ...           ...                 ...
# 176595                    5              6             1               16691
# 176596                  124              7             2               27569
# 176597                   18              6             1                8244
# 176598                    9              5             2               10718
# 176599                    0             12             2               15390
#
#         total_damage_dealt   win  side  \
# 0                   156270  True  BLUE
# 1                   152183  True  BLUE
# 2                   177681  True  BLUE
# 3                   228328  True  BLUE
# 4                    34299  True  BLUE
# ...                    ...   ...   ...
# 176595              144141  True  BLUE
# 176596              159701  True  BLUE
# 176597              164088  True  BLUE
# 176598              146160  True  BLUE
# 176599               13855  True  BLUE
#
#                                                   game_id
# 0       EU Challenger Series/2017 Season/Spring Qualif...
# 1       EU Challenger Series/2017 Season/Spring Qualif...
# 2       EU Challenger Series/2017 Season/Spring Qualif...
# 3       EU Challenger Series/2017 Season/Spring Qualif...
# 4       EU Challenger Series/2017 Season/Spring Qualif...
# ...                                                   ...
# 176595    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_4
# 176596    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_4
# 176597    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_4
# 176598    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_4
# 176599    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_4
#
# [94620 rows x 19 columns]

# %%
df_RED_WIN = df_RED[df_RED['win'] == True]
df_RED_WIN
# Out:
#                name        id role champion_name  champion_id  gold_15  \
# 5              Arin  190279.0  TOP          Shen           98   4707.0
# 6       Pridestalkr  194373.0  JGL      Nocturne           56   5826.0
# 7           Larssen  177025.0  MID        Syndra          134   5335.0
# 8            SMILEY  205007.0  BOT          Ashe           22   6467.0
# 9             Hadow  163748.0  SUP      Malzahar           90   3507.0
# ...             ...       ...  ...           ...          ...      ...
# 176580        CuVee  145319.0  TOP        Maokai           57   5410.0
# 176581     Ambition  189721.0  JGL       Rek'Sai          421   5038.0
# 176582        Crown  142619.0  MID       Orianna           61   5302.0
# 176583        Ruler  196493.0  BOT         Sivir           15   5458.0
# 176584       CoreJJ  137426.0  SUP         Karma           43   3494.0
#
#         kills_assists_15  deaths_15  total_gold  total_cs  total_kills  \
# 5                   19.0        0.0       12968       210            6
# 6                   15.0        1.0       11986       159            7
# 7                   15.0        1.0       13118       278            5
# 8                   17.0        2.0       14181       246            9
# 9                   15.0        2.0        8631        16            0
# ...                  ...        ...         ...       ...          ...
# 176580               2.0        0.0       13602       321            0
# 176581               4.0        2.0       13766       245            1
# 176582              10.0        1.0       17675       354            9
# 176583               8.0        1.0       17111       409            2
# 176584              10.0        1.0       10743        26            0
#
#         total_monster_kills  total_assists  total_deaths  total_damage_taken  \
# 5                         1             13             0               21463
# 6                       135              8             1               26557
# 7                         7             10             1               13295
# 8                        10              8             2               16716
# 9                         0             15             2               13399
# ...                     ...            ...           ...                 ...
# 176580                    0              2             0               25464
# 176581                  206              3             2               43240
# 176582                   22              1             1               10901
# 176583                   14              6             1               12571
# 176584                    1             10             1                8494
#
#         total_damage_dealt   win side  \
# 5                   104438  True  RED
# 6                   175986  True  RED
# 7                   184311  True  RED
# 8                   169901  True  RED
# 9                    27741  True  RED
# ...                    ...   ...  ...
# 176580              192722  True  RED
# 176581              229578  True  RED
# 176582              257123  True  RED
# 176583              318955  True  RED
# 176584               24057  True  RED
#
#                                                   game_id
# 5       EU Challenger Series/2017 Season/Spring Qualif...
# 6       EU Challenger Series/2017 Season/Spring Qualif...
# 7       EU Challenger Series/2017 Season/Spring Qualif...
# 8       EU Challenger Series/2017 Season/Spring Qualif...
# 9       EU Challenger Series/2017 Season/Spring Qualif...
# ...                                                   ...
# 176580    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_1
# 176581    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_1
# 176582    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_1
# 176583    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_1
# 176584    IEM Season 11/Gyeonggi/Scoreboards/Playoffs_3_1
#
# [81980 rows x 19 columns]

# %%
df_BLUE_CHAMPWINS = df_BLUE_WIN[["champion_name","champion_id","win"]]
df_BLUE_CHAMPWINS.head(10)
# Out:
#    champion_name  champion_id   win
# 0       Nautilus          111  True
# 1        Lee Sin           64  True
# 2         Syndra          134  True
# 3           Jhin          202  True
# 4          Karma           43  True
# 15         Poppy           78  True
# 16       Camille          164  True
# 17       Orianna           61  True
# 18          Jhin          202  True
# 19      Malzahar           90  True

# %%
df_RED_CHAMPWINS = df_RED_WIN[["champion_name","champion_id","win"]]
df_RED_CHAMPWINS.head(10)
# Out:
#    champion_name  champion_id   win
# 5           Shen           98  True
# 6       Nocturne           56  True
# 7         Syndra          134  True
# 8           Ashe           22  True
# 9       Malzahar           90  True
# 10         Poppy           78  True
# 11       Kha'Zix          121  True
# 12        Syndra          134  True
# 13        Ezreal           81  True
# 14         Karma           43  True

# %%
df_BLUE_CHAMPWINS["champion_name"].value_counts(normalize=True)
# Out:
# Braum        0.024678
# Ezreal       0.024657
# Gragas       0.022183
# Thresh       0.021253
# Kai'Sa       0.018558
#                ...
# Annie        0.000085
# Master Yi    0.000074
# Shaco        0.000074
# Teemo        0.000074
# Viego        0.000042
# Name: champion_name, Length: 154, dtype: float64

# %%
df_BLUE_CHAMPWINS["champion_id"].value_counts(normalize=True)
# Out:
# 201    0.024678
# 81     0.024657
# 79     0.022183
# 412    0.021253
# 145    0.018558
#          ...
# 1      0.000085
# 11     0.000074
# 35     0.000074
# 17     0.000074
# 234    0.000042
# Name: champion_id, Length: 154, dtype: float64

# %%
df_RED_CHAMPWINS["champion_name"].value_counts(normalize=True)
# Out:
# Braum        0.025714
# Ezreal       0.025287
# Gragas       0.023201
# Thresh       0.022896
# Kai'Sa       0.019554
#                ...
# Master Yi    0.000098
# Teemo        0.000085
# Amumu        0.000061
# Viego        0.000024
# Gwen         0.000012
# Name: champion_name, Length: 155, dtype: float64

# %% [markdown]
# ## Patch/Date Splitting

# %%
df_teams['patch'].value_counts()
# Out:
# 11.4     910
# 11.2     879
# 9.13     868
# 10.14    791
# 11.3     726
#         ...
# 7.23      19
# 7.21      19
# 9.18      12
# 8.18       9
# 8.7        9
# Name: patch, Length: 120, dtype: int64

# %%
## Assigning each patch that starts with a number to a year
#6 - 2016, 7 -2017, 8 -2018, 9-2019, 10-2020, 11-2022



df_teams['patch_year'] = df.apply('patch', axis=1)
